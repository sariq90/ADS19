# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

x, y = np.loadtxt("C:\Repos\cpp\ADS-P\P04_Sorting\omp_quicksort_nomed.txt", delimiter='\t', unpack=True)
plt.plot(x,y,'b-',label='Quick Sort (-median)')
x, y = np.loadtxt("C:\Repos\cpp\ADS-P\P04_Sorting\omp_quicksort.txt", delimiter='\t', unpack=True)
plt.plot(x,y,'c-',label='Quick Sort (+median)')
x, y = np.loadtxt("C:\Repos\cpp\ADS-P\P04_Sorting\omp_heapsort.txt", delimiter='\t', unpack=True)
plt.plot(x,y,'r-',label='Heap Sort')
x, y = np.loadtxt("C:\Repos\cpp\ADS-P\P04_Sorting\omp_shellsort.txt", delimiter='\t', unpack=True)
plt.plot(x,y,'y-',label='Shell Sort')
x, y = np.loadtxt("C:\Repos\cpp\ADS-P\P04_Sorting\omp_mergesort.txt", delimiter='\t', unpack=True)
plt.plot(x,y,'g-',label='Merge Sort')

plt.xlabel('n [-]')
plt.ylabel('t [s]')

plt.legend(loc='best')

plt.show()
# Out:
# <img src="data:image/png;base64,...">
